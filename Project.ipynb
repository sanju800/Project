# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
myexcel=pd.read_csv('Desktop/Entri/myexcel - myexcel.csv.csv')
myexcel
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# 1) Changing the column 'Height' having the incorrect data with any random numbers between 150 and 180

# %%
myexcel['Height']=np.random.randint(150,180,size=len(myexcel))

# %%
print("Modified 'Height' column")
print(myexcel['Height'])
# Out:
# Modified 'Height' column
# 0      173
# 1      174
# 2      175
# 3      172
# 4      150
#       ...
# 453    168
# 454    178
# 455    163
# 456    168
# 457    160
# Name: Height, Length: 458, dtype: int32

# %% [markdown]
# 2) How many are there in each team and the percentage splitting with respect to the total employees

# %%
team_count=myexcel['Team'].value_counts()
percentage=(team_count/len(myexcel))*100
summary=pd.DataFrame({'Count':team_count,'Percentage':percentage})
summary
# Out:
#                         Count  Percentage
# Team
# New Orleans Pelicans       19    4.148472
# Memphis Grizzlies          18    3.930131
# Utah Jazz                  16    3.493450
# New York Knicks            16    3.493450
# Milwaukee Bucks            16    3.493450
# Brooklyn Nets              15    3.275109
# Portland Trail Blazers     15    3.275109
# Oklahoma City Thunder      15    3.275109
# Denver Nuggets             15    3.275109
# Washington Wizards         15    3.275109
# Miami Heat                 15    3.275109
# Charlotte Hornets          15    3.275109
# Atlanta Hawks              15    3.275109
# San Antonio Spurs          15    3.275109
# Houston Rockets            15    3.275109
# Boston Celtics             15    3.275109
# Indiana Pacers             15    3.275109
# Detroit Pistons            15    3.275109
# Cleveland Cavaliers        15    3.275109
# Chicago Bulls              15    3.275109
# Sacramento Kings           15    3.275109
# ...

# %% [markdown]
# 3) Segregate the employees w.r.t different positions

# %%
c=myexcel['Position'].value_counts()
c
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %% [markdown]
# 4) Find from which age group most of the employees belongs to

# %%
age_count=myexcel['Age'].value_counts()
age_count
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %% [markdown]
# 5) Find out under which team and position, spending in terms of salary is high

# %%
salary_spending=myexcel.groupby(['Team','Position'])['Salary'].sum().idxmax()
salary_spending
# Out:
# ('Los Angeles Lakers', 'SF')

# %% [markdown]
# 6) Find if there is any correlation between Age and Salary, represent it visually

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Age',y='Salary',data=myexcel)
plt.title('Correlation between Age and Salary')
plt.xlabel('age')
plt.ylabel('salary')
plt.show()
